# %%
import os
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dirname = '/content/drive/My Drive/Research/mobile-cellular-subscriptions-per-100-people.csv'

# %%
data = pd.read_csv('/content/drive/My Drive/mobile-cellular-subscriptions-per-100-people.csv')

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df =pd.DataFrame(data=data)
print(df)
# Out:
#             Entity Code  Year  Mobile cellular subscriptions (per 100 people)
# 0      Afghanistan  AFG  1960                                        0.000000
# 1      Afghanistan  AFG  1965                                        0.000000
# 2      Afghanistan  AFG  1970                                        0.000000
# 3      Afghanistan  AFG  1975                                        0.000000
# 4      Afghanistan  AFG  1976                                        0.000000
# ...            ...  ...   ...                                             ...
# 11890     Zimbabwe  ZWE  2015                                       92.347105
# 11891     Zimbabwe  ZWE  2016                                       91.793458
# 11892     Zimbabwe  ZWE  2017                                       98.985073
# 11893     Zimbabwe  ZWE  2018                                       89.404869
# 11894     Zimbabwe  ZWE  2019                                       90.102290
#
# [11895 rows x 4 columns]

# %%
plt.hist(df['Mobile cellular subscriptions (per 100 people)'])
# Out:
# (array([8.309e+03, 9.170e+02, 1.160e+03, 1.134e+03, 2.970e+02, 5.500e+01,
#         1.100e+01, 4.000e+00, 3.000e+00, 5.000e+00]),
#  array([  0.        ,  34.53245224,  69.06490448, 103.59735672,
#         138.12980896, 172.6622612 , 207.19471344, 241.72716568,
#         276.25961792, 310.79207016, 345.3245224 ]),
#  <a list of 10 Patch objects>)

# %%
data.head()
# Out:
#         Entity Code  Year  Mobile cellular subscriptions (per 100 people)
# 0  Afghanistan  AFG  1960                                             0.0
# 1  Afghanistan  AFG  1965                                             0.0
# 2  Afghanistan  AFG  1970                                             0.0
# 3  Afghanistan  AFG  1975                                             0.0
# 4  Afghanistan  AFG  1976                                             0.0

# %%
data.head(10)
# Out:
#         Entity Code  Year  Mobile cellular subscriptions (per 100 people)
# 0  Afghanistan  AFG  1960                                             0.0
# 1  Afghanistan  AFG  1965                                             0.0
# 2  Afghanistan  AFG  1970                                             0.0
# 3  Afghanistan  AFG  1975                                             0.0
# 4  Afghanistan  AFG  1976                                             0.0
# 5  Afghanistan  AFG  1977                                             0.0
# 6  Afghanistan  AFG  1978                                             0.0
# 7  Afghanistan  AFG  1979                                             0.0
# 8  Afghanistan  AFG  1980                                             0.0
# 9  Afghanistan  AFG  1981                                             0.0

# %%
data.tail()
# Out:
#          Entity Code  Year  Mobile cellular subscriptions (per 100 people)
# 11890  Zimbabwe  ZWE  2015                                       92.347105
# 11891  Zimbabwe  ZWE  2016                                       91.793458
# 11892  Zimbabwe  ZWE  2017                                       98.985073
# 11893  Zimbabwe  ZWE  2018                                       89.404869
# 11894  Zimbabwe  ZWE  2019                                       90.102290

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11895 entries, 0 to 11894
# Data columns (total 4 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Entity                                          11895 non-null  object
#  1   Code                                            9645 non-null   object
#  2   Year                                            11895 non-null  int64
#  3   Mobile cellular subscriptions (per 100 people)  11895 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 371.8+ KB

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.describe(include='all')
# Out:
#              Entity  Code          Year  \
# count         11895  9645  11895.000000
# unique          262   215           NaN
# top     Afghanistan   AFG           NaN
# freq             48    48           NaN
# mean            NaN   NaN   1995.011938
# std             NaN   NaN     14.761475
# min             NaN   NaN   1960.000000
# 25%             NaN   NaN   1984.000000
# 50%             NaN   NaN   1996.000000
# 75%             NaN   NaN   2007.000000
# max             NaN   NaN   2019.000000
#
#         Mobile cellular subscriptions (per 100 people)
# count                                     11895.000000
# unique                                             NaN
# top                                                NaN
# freq                                               NaN
# mean                                         30.839729
# std                                          47.433838
# min                                           0.000000
# ...

# %%
data[['Entity','Code','Year','Mobile cellular subscriptions (per 100 people)']] = data[['Entity','Code','Year','Mobile cellular subscriptions (per 100 people)']].replace(0,np.NaN)

# %%
data.isnull().sum()
# Out:
# Entity                                               0
# Code                                              2250
# Year                                                 0
# Mobile cellular subscriptions (per 100 people)    4737
# dtype: int64

# %%
data.hist(figsize = (13,13), color="#076543")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6c03e7f150>,
# ...
#       dtype=object)

# %%
data.isnull().sum()
# Out:
# Entity                                               0
# Code                                              2250
# Year                                                 0
# Mobile cellular subscriptions (per 100 people)    4737
# dtype: int64

# %%
data.corr()
# Out:
#                                                     Year  \
# Year                                            1.000000
# Mobile cellular subscriptions (per 100 people)  0.773777
#
#                                                 Mobile cellular subscriptions (per 100 people)
# Year                                                                                  0.773777
# Mobile cellular subscriptions (per 100 people)                                        1.000000

# %%
data.columns
# Out:
# Index(['Entity', 'Code', 'Year',
#        'Mobile cellular subscriptions (per 100 people)'],
#       dtype='object')

# %%
data.shape
# Out:
# (11895, 4)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11895 entries, 0 to 11894
# Data columns (total 4 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Entity                                          11895 non-null  object
#  1   Code                                            9645 non-null   object
#  2   Year                                            11895 non-null  int64
#  3   Mobile cellular subscriptions (per 100 people)  7158 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 371.8+ KB

# %%
data['Mobile cellular subscriptions (per 100 people)'].value_counts()
# Out:
# 32.302099     6
# 73.596166     2
# 58.394144     2
# 2.669941      2
# 4.223227      2
#              ..
# 137.753840    1
# 138.280969    1
# 128.981661    1
# 147.543495    1
# 90.102290     1
# Name: Mobile cellular subscriptions (per 100 people), Length: 7083, dtype: int64

# %%
data.dtypes
# Out:
# Entity                                             object
# Code                                               object
# Year                                                int64
# Mobile cellular subscriptions (per 100 people)    float64
# dtype: object

# %%
data.isnull()
# Out:
#        Entity   Code   Year  Mobile cellular subscriptions (per 100 people)
# 0       False  False  False                                            True
# 1       False  False  False                                            True
# 2       False  False  False                                            True
# 3       False  False  False                                            True
# 4       False  False  False                                            True
# ...       ...    ...    ...                                             ...
# 11890   False  False  False                                           False
# 11891   False  False  False                                           False
# 11892   False  False  False                                           False
# 11893   False  False  False                                           False
# 11894   False  False  False                                           False
#
# [11895 rows x 4 columns]

# %%
missing_values_count = data.isnull().sum()

# %%
missing_values_count[0:10]
# Out:
# Entity                                               0
# Code                                              2250
# Year                                                 0
# Mobile cellular subscriptions (per 100 people)    4737
# dtype: int64

# %%
x = data.iloc[:,:-1].values
y = data.iloc[:,-1].values

# %%
data.dropna()
# Out:
#             Entity Code  Year  Mobile cellular subscriptions (per 100 people)
# 30     Afghanistan  AFG  2002                                        0.110616
# 31     Afghanistan  AFG  2003                                        0.844564
# 32     Afghanistan  AFG  2004                                        2.426528
# 33     Afghanistan  AFG  2005                                        4.677583
# 34     Afghanistan  AFG  2006                                        9.534905
# ...            ...  ...   ...                                             ...
# 11890     Zimbabwe  ZWE  2015                                       92.347105
# 11891     Zimbabwe  ZWE  2016                                       91.793458
# 11892     Zimbabwe  ZWE  2017                                       98.985073
# 11893     Zimbabwe  ZWE  2018                                       89.404869
# 11894     Zimbabwe  ZWE  2019                                       90.102290
#
# [5579 rows x 4 columns]

# %%
columns_with_na_dropped = data.dropna(axis=1)
columns_with_na_dropped.head()
# Out:
#         Entity  Year
# 0  Afghanistan  1960
# 1  Afghanistan  1965
# 2  Afghanistan  1970
# 3  Afghanistan  1975
# 4  Afghanistan  1976

# %%
from sklearn.model_selection import train_test_split
x = data.drop(['Mobile cellular subscriptions (per 100 people)'],axis=1)
y = data['Mobile cellular subscriptions (per 100 people)']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=1)

# %%
x_train.shape, y_train.shape
# Out:
# ((9516, 3), (9516,))

# %%
x_test.shape, y_test.shape
# Out:
# ((2379, 3), (2379,))

# %%
import numpy as np
from sklearn.metrics import f1_score

# %%
actual = np.repeat([1, 0], repeats=[99, 55])

# %%
pred = np.repeat([1, 0, 1, 0], repeats=[86, 13, 20, 35])

# %%
import seaborn as sns
corr = data.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);
